# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Environment Ready!")

# %%
import os

print(os.getcwd())

# %%
import os

print(os.listdir())

# %%
import os

print(os.listdir("../Data/Raw_data"))

# %%
import os

print(os.listdir("../Data/Raw_data/Superstore.csv"))

# %%
import pandas as pd

df = pd.read_csv("../Data/Raw_data/Superstore.csv/Sample - Superstore.csv", encoding='latin-1')

df.head()

# %%
import os

print("Current folder:", os.getcwd())

print("\nData folder:")
print(os.listdir("../Data"))

print("\nRaw_data folder:")
print(os.listdir("../Data/Raw_data"))

# %%
import os

print(os.listdir("../Data/Raw_data/Superstore.csv"))

# %%
import pandas as pd

df = pd.read_csv("../Data/Raw_data/Superstore.csv/Sample - Superstore.csv", encoding='latin-1')

print(df.head())

# %%
import os

print(os.listdir("../Data/Raw_data/Superstore.csv"))

# %%
import pandas as pd

df = pd.read_csv("../Data/Raw_data/Superstore.csv/Sample - Superstore.csv", encoding='latin-1')

df.head()

# %%
print("Rows and Columns:")
print(df.shape)

# %%
print(df.info())

# %%
df.head()

# %%
df.tail()

# %%
print("Missing Values:")
print(df.isnull().sum())

# %%
print("Duplicate Rows:")
print(df.duplicated().sum())

# %%
df.describe()

# %%
print(df.columns)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['Sales'], bins=30)
plt.title("Sales Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Profit'], bins=30)
plt.title("Profit Distribution")
plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar')
plt.title("Sales by Category")
plt.show()

# %%
region_sales = df.groupby('Region')['Sales'].sum()

region_sales.plot(kind='bar')
plt.title("Sales by Region")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8,5))
sns.heatmap(df[['Sales','Profit','Quantity','Discount']].corr(),
            annot=True,
            cmap='coolwarm')

plt.title("Correlation Matrix")
plt.show()

# %%
print("BUSINESS INSIGHTS")

# %%
category_sales = df.groupby('Category')['Sales'].sum()

category_sales.plot(kind='bar')
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# %%
profit_category = df.groupby('Category')['Profit'].sum()

profit_category.plot(kind='bar')
plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Sales'], bins=30)
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
import os

print(os.listdir("../Data/Raw_data"))

# %%
import os

print(os.listdir("../Data/Raw_data/Superstore.csv"))
